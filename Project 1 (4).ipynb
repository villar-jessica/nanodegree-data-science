# %% [markdown]
# # Gender equality in leadership: A data-driven analysis
# ## Investigating factors that drive female representation in management
#
# **Author:** Jéssica Villar
#
# **Date:** February 2026
#
# **Dataset:** World Bank Gender Statistics (17 Latin American countries, 2015-2024)
#
# ### Executive Summary
#
# This project investigates **factors influencing female representation in business leadership positions** using World Bank data with **complete preprocessing pipeline** including pivot tables and null value handling.
#
# ### Key business questions
#
# 1. Which educational factors have the greatest impact on female leadership?
# 2. How does economic development influence gender equality?
# 3. What is the relationship between employment quality and female leadership?
# 4. Which interventions provide the highest ROI?

# %% [markdown]
# # 1. Setup and configurations

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/venv/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /opt/venv/lib/python3.10/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Data manipulation
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics
from scipy import stats

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Custom class
from gender_equality_analyzer import GenderEqualityAnalyzer, plot_correlation_analysis

# Configuration
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 6)
np.random.seed(42)

# %% [markdown]
# # 2. Data loading and preprocessing

# %%
# Initialize analyzer
analyzer = GenderEqualityAnalyzer()

# Load data
analyzer.load_world_bank_data(
    filepath='p_data_extract_from_gender_statistics.xlsx',
#     value_col='value',  # Column containing numeric values
#     convert_missing=True  # Convert '..' to NaN
)
# Out:
# Data loaded successfully!
#   Dimensions: 423 rows x 14 columns
#   Data period: 2015 - 2024
#   Years available: 10
#                                            Series Name           Series Code  \
# 0    Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 1    Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 2    Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 3    Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# 4    Female share of graduates from Science, Techno...  SE.TER.GRAD.FE.SI.ZS
# ..                                                 ...                   ...
# 418                                                NaN                   NaN
# 419                                                NaN                   NaN
# 420                                                NaN                   NaN
# 421              Data from database: Gender Statistics                   NaN
# 422                           Last Updated: 02/02/2026                   NaN
#
#     Country Name Country Code 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# 0         Brazil          BRA     34.446522      35.20026     36.644058
# 1         Mexico          MEX     31.331949     31.133751     30.628151
# 2      Argentina          ARG            ..            ..            ..
# 3          Chile          CHL     18.209129      18.47369     18.828581
# 4        Bolivia          BOL            ..            ..            ..
# ..           ...          ...           ...           ...           ...
# 418          NaN          NaN           NaN           NaN           NaN
# 419          NaN          NaN           NaN           NaN           NaN
# 420          NaN          NaN           NaN           NaN           NaN
# 421          NaN          NaN           NaN           NaN           NaN
# 422          NaN          NaN           NaN           NaN           NaN
#
#     2018 [YR2018] 2019 [YR2019] 2020 [YR2020] 2021 [YR2021] 2022 [YR2022]  \
# 0       35.011391     35.011002     33.679611            ..     31.872761
# 1              ..     31.262871     32.070141     32.908489     33.673168
# 2       47.565578     48.353649     48.598209      47.93745     48.476681
# 3        18.67831      19.15946      20.08836      19.54347     20.935011
# 4              ..            ..            ..            ..            ..
# ..            ...           ...           ...           ...           ...
# 418           NaN           NaN           NaN           NaN           NaN
# 419           NaN           NaN           NaN           NaN           NaN
# 420           NaN           NaN           NaN           NaN           NaN
# 421           NaN           NaN           NaN           NaN           NaN
# 422           NaN           NaN           NaN           NaN           NaN
#
#     2023 [YR2023] 2024 [YR2024]
# 0        30.52029            ..
# 1       34.420769            ..
# 2       46.754929            ..
# 3        20.56444            ..
# 4              ..            ..
# ..            ...           ...
# 418           NaN           NaN
# 419           NaN           NaN
# 420           NaN           NaN
# 421           NaN           NaN
# 422           NaN           NaN
#
# [423 rows x 14 columns]

# %%
# Transform to long
analyzer.transform_to_long()
# Out:
# Transforming from wide to long format...
#    ID variables: ['Country Name', 'Country Code', 'Series Code']
#    Year columns: 10
#    Transformation complete!
#    Long format: 2,929 rows
#    Removed 1,301 rows with null values
#             Country Name Country Code           Series Code      value  year
# 0                 Brazil          BRA  SE.TER.GRAD.FE.SI.ZS  34.446522  2015
# 1                 Mexico          MEX  SE.TER.GRAD.FE.SI.ZS  31.331949  2015
# 3                  Chile          CHL  SE.TER.GRAD.FE.SI.ZS  18.209129  2015
# 5               Colombia          COL  SE.TER.GRAD.FE.SI.ZS  33.118610  2015
# 6                Ecuador          ECU  SE.TER.GRAD.FE.SI.ZS  28.070391  2015
# ...                  ...          ...                   ...        ...   ...
# 4190                Peru          PER           SI.POV.GINI  40.100000  2024
# 4192             Uruguay          URY           SI.POV.GINI  40.000000  2024
# 4195  Dominican Republic          DOM           SI.POV.GINI  39.000000  2024
# 4197              Panama          PAN           SI.POV.GINI  49.700000  2024
# 4199            Honduras          HND           SI.POV.GINI  45.700000  2024
#
# [2929 rows x 5 columns]

# %%
# Map World Bank codes to readable names
analyzer.map_variables(
    series_code_col='Series Code',
    keep_unmapped=False  # Remove indicators not in our mapping (recommended)
)
# Out:
# Mapping World Bank variable codes to readable names...
#    Total mapping rules: 19
#    Mapped: 2,929 rows (692.4%)
#    Unmapped: 0 rows (0.0%)
#    Removed 0 unmapped rows
#    Final: 2,929 rows with 19 unique variables
#             Country Name Country Code           Series Code      value  year  \
# 0                 Brazil          BRA  SE.TER.GRAD.FE.SI.ZS  34.446522  2015
# 1                 Mexico          MEX  SE.TER.GRAD.FE.SI.ZS  31.331949  2015
# 3                  Chile          CHL  SE.TER.GRAD.FE.SI.ZS  18.209129  2015
# 5               Colombia          COL  SE.TER.GRAD.FE.SI.ZS  33.118610  2015
# 6                Ecuador          ECU  SE.TER.GRAD.FE.SI.ZS  28.070391  2015
# ...                  ...          ...                   ...        ...   ...
# 4190                Peru          PER           SI.POV.GINI  40.100000  2024
# 4192             Uruguay          URY           SI.POV.GINI  40.000000  2024
# 4195  Dominican Republic          DOM           SI.POV.GINI  39.000000  2024
# 4197              Panama          PAN           SI.POV.GINI  49.700000  2024
# 4199            Honduras          HND           SI.POV.GINI  45.700000  2024
#
#            variable_name
# 0     pct_graduadas_stem
# 1     pct_graduadas_stem
# 3     pct_graduadas_stem
# 5     pct_graduadas_stem
# 6     pct_graduadas_stem
# ...                  ...
# 4190         indice_gini
# 4192         indice_gini
# 4195         indice_gini
# 4197         indice_gini
# 4199         indice_gini
#
# [2929 rows x 6 columns]

# %%
# Pivot to wide format
analyzer.pivot_data(
    index_cols=['Country Name', 'Country Code', 'year'],  # Unique observation identifiers
    columns_col='variable_name',  # Column with readable indicator names
    values_col='value'            # Column with numeric values
)
# Out:
# Pivoting data from long to wide format...
#    Index columns: ['Country Name', 'Country Code', 'year']
#    Columns from: variable_name
#    Values from: value
# Pivoting complete!
# Wide format: 220 rows x 22 columns
# Created 19 indicator columns
#       Country Name Country Code  year  desemprego_edu_avancada_feminino  \
# 0        Argentina          ARG  2015                               NaN
# 1        Argentina          ARG  2016                               NaN
# 2        Argentina          ARG  2017                             3.971
# 3        Argentina          ARG  2018                             4.201
# 4        Argentina          ARG  2019                             4.395
# ..             ...          ...   ...                               ...
# 215  Venezuela, RB          VEN  2020                               NaN
# 216  Venezuela, RB          VEN  2021                               NaN
# 217  Venezuela, RB          VEN  2022                               NaN
# 218  Venezuela, RB          VEN  2023                               NaN
# 219  Venezuela, RB          VEN  2024                               NaN
#
#      desemprego_edu_avancada_masculino  desemprego_feminino  \
# 0                                  NaN                8.704
# 1                                  NaN                9.227
# 2                                2.322                9.485
# 3                                2.881               10.563
# 4                                3.180               10.718
# ..                                 ...                  ...
# 215                                NaN                7.907
# 216                                NaN                7.541
# 217                                NaN                6.179
# 218                                NaN                5.937
# 219                                NaN                5.845
#
#      desemprego_masculino  empregadas_assalariadas  empregados_assalariados  \
# 0                   6.796                79.918961                72.997085
# 1                   7.291                79.242334                72.442691
# 2                   7.544                78.597119                71.942072
# 3                   8.246                77.472436                72.348449
# 4                   9.202                76.633238                71.232437
# ..                    ...                      ...                      ...
# 215                 7.287                64.085996                57.891393
# 216                 6.693                65.579221                58.434215
# 217                 5.352                63.856243                58.325870
# 218                 5.108                63.003974                57.953062
# 219                 5.017                62.503286                58.013227
#
#      empresas_gerente_feminina  ...  indice_gini  \
# 0                          NaN  ...          NaN
# 1                          NaN  ...         42.3
# 2                     7.985743  ...         41.4
# 3                          NaN  ...         41.7
# 4                          NaN  ...         43.3
# ..                         ...  ...          ...
# 215                        NaN  ...          NaN
# 216                        NaN  ...          NaN
# 217                        NaN  ...          NaN
# 218                        NaN  ...          NaN
# 219                        NaN  ...          NaN
#
#      matricula_secundaria_feminina  matricula_superior_feminina  \
# 0                       111.491547                   105.026185
# 1                       112.874443                   109.302620
# 2                       113.530090                   112.844352
# 3                       112.869537                   114.838632
# 4                       113.605873                   120.836338
# ..                             ...                          ...
# 215                            NaN                          NaN
# 216                            NaN                          NaN
# 217                     100.249550                          NaN
# 218                     101.692711                          NaN
# 219                     102.248581                          NaN
#
#      mulheres_parlamento  participacao_trabalho_feminina  pct_graduadas_stem  \
# 0                    NaN                          47.498                 NaN
# 1              35.797665                          47.582                 NaN
# 2              38.132296                          47.666                 NaN
# 3              38.910506                          49.146           47.565578
# 4              40.157480                          50.000           48.353649
# ..                   ...                             ...                 ...
# 215            22.155689                          36.887                 NaN
# 216            22.155689                          37.368                 NaN
# 217                  NaN                          35.320                 NaN
# 218                  NaN                          36.158                 NaN
# 219                  NaN                          37.332                 NaN
#
#      pct_mulheres_gerencia  pib_per_capita  razao_fm_participacao_trabalho  \
# 0                      NaN    13679.626498                       66.451216
# 1                      NaN    12699.962314                       67.066020
# 2                   32.629    14532.500931                       67.693925
# 3                   33.178    11752.799892                       69.744274
# 4                   33.136     9955.974787                       70.441386
# ..                     ...             ...                             ...
# 215                    NaN     1506.043621                       61.461943
# 216                    NaN     2004.933979                       61.855261
# 217                    NaN     3155.042071                       52.536070
# 218                    NaN     3617.435946                       53.687508
# 219                    NaN     4217.591026                       55.287009
#
#      uso_internet
# 0         68.0431
# 1         70.9690
# 2         74.2949
# 3         77.7000
# 4         79.9470
# ..            ...
# 215           NaN
# 216           NaN
# 217           NaN
# 218           NaN
# 219           NaN
#
# [220 rows x 22 columns]

# %%
# Remove columns with >60% null values
analyzer.remove_high_null_columns(
    threshold=0.6,  # Maximum 60% nulls allowed
    verbose=True    # Print removed columns
)
# Out:
# Removing columns with >60% null values...
#
#    Columns being removed (3):
#       - empresas_gerente_feminina                                              (90.9% null)
#       - empresas_proprietaria_feminina                                         (90.9% null)
#       - indice_capital_humano                                                  (76.8% null)
#
#    Removed 3 columns
#    Remaining: 19 columns
#    Data shape: 220 rows x 19 columns
#       Country Name Country Code  year  desemprego_edu_avancada_feminino  \
# 0        Argentina          ARG  2015                               NaN
# 1        Argentina          ARG  2016                               NaN
# 2        Argentina          ARG  2017                             3.971
# 3        Argentina          ARG  2018                             4.201
# 4        Argentina          ARG  2019                             4.395
# ..             ...          ...   ...                               ...
# 215  Venezuela, RB          VEN  2020                               NaN
# 216  Venezuela, RB          VEN  2021                               NaN
# 217  Venezuela, RB          VEN  2022                               NaN
# 218  Venezuela, RB          VEN  2023                               NaN
# 219  Venezuela, RB          VEN  2024                               NaN
#
#      desemprego_edu_avancada_masculino  desemprego_feminino  \
# 0                                  NaN                8.704
# 1                                  NaN                9.227
# 2                                2.322                9.485
# 3                                2.881               10.563
# 4                                3.180               10.718
# ..                                 ...                  ...
# 215                                NaN                7.907
# 216                                NaN                7.541
# 217                                NaN                6.179
# 218                                NaN                5.937
# 219                                NaN                5.845
#
#      desemprego_masculino  empregadas_assalariadas  empregados_assalariados  \
# 0                   6.796                79.918961                72.997085
# 1                   7.291                79.242334                72.442691
# 2                   7.544                78.597119                71.942072
# 3                   8.246                77.472436                72.348449
# 4                   9.202                76.633238                71.232437
# ..                    ...                      ...                      ...
# 215                 7.287                64.085996                57.891393
# 216                 6.693                65.579221                58.434215
# 217                 5.352                63.856243                58.325870
# 218                 5.108                63.003974                57.953062
# 219                 5.017                62.503286                58.013227
#
#      indice_gini  matricula_secundaria_feminina  matricula_superior_feminina  \
# 0            NaN                     111.491547                   105.026185
# 1           42.3                     112.874443                   109.302620
# 2           41.4                     113.530090                   112.844352
# 3           41.7                     112.869537                   114.838632
# 4           43.3                     113.605873                   120.836338
# ..           ...                            ...                          ...
# 215          NaN                            NaN                          NaN
# 216          NaN                            NaN                          NaN
# 217          NaN                     100.249550                          NaN
# 218          NaN                     101.692711                          NaN
# 219          NaN                     102.248581                          NaN
#
#      mulheres_parlamento  participacao_trabalho_feminina  pct_graduadas_stem  \
# 0                    NaN                          47.498                 NaN
# 1              35.797665                          47.582                 NaN
# 2              38.132296                          47.666                 NaN
# 3              38.910506                          49.146           47.565578
# 4              40.157480                          50.000           48.353649
# ..                   ...                             ...                 ...
# 215            22.155689                          36.887                 NaN
# 216            22.155689                          37.368                 NaN
# 217                  NaN                          35.320                 NaN
# 218                  NaN                          36.158                 NaN
# 219                  NaN                          37.332                 NaN
#
#      pct_mulheres_gerencia  pib_per_capita  razao_fm_participacao_trabalho  \
# 0                      NaN    13679.626498                       66.451216
# 1                      NaN    12699.962314                       67.066020
# 2                   32.629    14532.500931                       67.693925
# 3                   33.178    11752.799892                       69.744274
# 4                   33.136     9955.974787                       70.441386
# ..                     ...             ...                             ...
# 215                    NaN     1506.043621                       61.461943
# 216                    NaN     2004.933979                       61.855261
# 217                    NaN     3155.042071                       52.536070
# 218                    NaN     3617.435946                       53.687508
# 219                    NaN     4217.591026                       55.287009
#
#      uso_internet
# 0         68.0431
# 1         70.9690
# 2         74.2949
# 3         77.7000
# 4         79.9470
# ..            ...
# 215           NaN
# 216           NaN
# 217           NaN
# 218           NaN
# 219           NaN
#
# [220 rows x 19 columns]

# %% [markdown]
# After removing high-null columns, we still have some missing values (now <60% per column). We impute these using **temporal methods by country**.
#
# **Method:** Forward Fill + Backward Fill **by country**
#
# **Advantages:**
# - Maintains real temporal patterns
# - Preserves country-specific trends
# - Enables complete dataset analysis
#
# **Limitations:**
# - May slightly underestimate variability
# - Assumes gradual changes (valid for most indicators)
# - Long gaps propagate outdated values

# %%
# Temporal imputation by country
analyzer.preprocess_data(
    fillna_method='both'  # Forward + backward fill
)
# Out:
# Preprocessing...
#    Missing values before: 682
#    Temporal imputation by country...
#    Missing values after imputation: 0
#    Rows removed (remaining NaNs): 80
#    Preprocessing complete!
#    Final dataset: 140 rows x 19 columns
#     Country Name Country Code  year  desemprego_edu_avancada_feminino  \
# 0      Argentina          ARG  2015                             3.971
# 1      Argentina          ARG  2016                             3.971
# 2      Argentina          ARG  2017                             3.971
# 3      Argentina          ARG  2018                             4.201
# 4      Argentina          ARG  2019                             4.395
# ..           ...          ...   ...                               ...
# 205      Uruguay          URY  2020                             3.027
# 206      Uruguay          URY  2021                             3.027
# 207      Uruguay          URY  2022                             1.574
# 208      Uruguay          URY  2023                             2.002
# 209      Uruguay          URY  2024                             1.878
#
#      desemprego_edu_avancada_masculino  desemprego_feminino  \
# 0                                2.322                8.704
# 1                                2.322                9.227
# 2                                2.322                9.485
# 3                                2.881               10.563
# 4                                3.180               10.718
# ..                                 ...                  ...
# 205                              2.993               12.442
# 206                              2.993               10.958
# 207                              1.665                9.050
# 208                              2.085                9.460
# 209                              1.957                9.406
#
#      desemprego_masculino  empregadas_assalariadas  empregados_assalariados  \
# 0                   6.796                79.918961                72.997085
# 1                   7.291                79.242334                72.442691
# 2                   7.544                78.597119                71.942072
# 3                   8.246                77.472436                72.348449
# 4                   9.202                76.633238                71.232437
# ..                    ...                      ...                      ...
# 205                 8.663                75.134127                68.621622
# 206                 7.913                74.530436                69.101547
# 207                 6.880                74.594665                69.231254
# 208                 7.428                74.250896                69.757444
# 209                 7.193                74.329548                69.893741
#
#      indice_gini  matricula_secundaria_feminina  matricula_superior_feminina  \
# 0           42.3                     111.491547                   105.026185
# 1           42.3                     112.874443                   109.302620
# 2           41.4                     113.530090                   112.844352
# 3           41.7                     112.869537                   114.838632
# 4           43.3                     113.605873                   120.836338
# ..           ...                            ...                          ...
# 205         40.2                     123.152969                    97.042226
# 206         40.8                     127.390487                    97.042226
# 207         40.6                     128.742960                    97.569386
# 208         40.9                     125.241045                   101.562689
# 209         40.0                     125.241045                   101.562689
#
#      mulheres_parlamento  participacao_trabalho_feminina  pct_graduadas_stem  \
# 0              35.797665                          47.498           47.565578
# 1              35.797665                          47.582           47.565578
# 2              38.132296                          47.666           47.565578
# 3              38.910506                          49.146           47.565578
# 4              40.157480                          50.000           48.353649
# ..                   ...                             ...                 ...
# 205            21.212121                          54.231           40.856750
# 206            24.242424                          56.034           43.186180
# 207            25.252525                          55.656           47.053452
# 208            26.262626                          56.518           40.019520
# 209            28.282828                          57.264           40.019520
#
#      pct_mulheres_gerencia  pib_per_capita  razao_fm_participacao_trabalho  \
# 0                   32.629    13679.626498                       66.451216
# 1                   32.629    12699.962314                       67.066020
# 2                   32.629    14532.500931                       67.693925
# 3                   33.178    11752.799892                       69.744274
# 4                   33.136     9955.974787                       70.441386
# ..                     ...             ...                             ...
# 205                 39.883    15757.535600                       79.053936
# 206                 39.822    17881.818721                       79.640131
# 207                 35.931    20818.614609                       77.968144
# 208                 33.871    23019.422156                       77.030434
# 209                 33.758    23906.513303                       77.954750
#
#      uso_internet
# 0         68.0431
# 1         70.9690
# 2         74.2949
# 3         77.7000
# 4         79.9470
# ..            ...
# 205       85.4710
# 206       87.6444
# 207       89.8730
# 208       89.8960
# 209       91.9911
#
# [140 rows x 19 columns]

# %% [markdown]
# # 3. Data engineering

# %%
# Feature engineering
X, y = analyzer.create_features(
    target_col='pct_mulheres_gerencia',
    exclude_cols=['Country Name', 'Country Code', 'year', 'Year']
)

print(f"\nDataset ready: {X.shape[0]} observations, {X.shape[1]} features")
# Out:
# Creating features...
#    Excluded: ['Country Name', 'Country Code', 'year', 'Year']
#    Target: pct_mulheres_gerencia
#    Features created!
#    15 features, 140 samples
#
# Dataset ready: 140 observations, 15 features

# %% [markdown]
# # 4. Exploratory data analysis

# %% [markdown]
# ## Question 1: which educational factors have the greatest impact on female leadership?

# %%
education_features = ['pct_graduadas_stem', 'matricula_superior_feminina', 'matricula_secundaria_feminina']
edu_corr = plot_correlation_analysis(
    X, y, 
    features=education_features,
    feature_category='Educational factors',
    top_n=3,
    color='steelblue'
)
# Out:
# EDUCATIONAL FACTORS - CORRELATION SUMMARY
#                       Feature  Correlation
# matricula_secundaria_feminina    -0.408400
#   matricula_superior_feminina    -0.167512
#            pct_graduadas_stem    -0.050365

# %% [markdown]
# All educational factors analyzed show a negative linear correlation with the percentage of women in management, with secondary education being the factor with the strongest relationship.

# %% [markdown]
# ## Question 2: how does economic development influence gender equality?

# %%
economic_features = ['pib_per_capita', 'indice_gini']
econ_corr = plot_correlation_analysis(
    X, y,
    features=economic_features, 
    feature_category='Economic development',
    top_n=2,
    color='green'
)
# Out:
# ECONOMIC DEVELOPMENT - CORRELATION SUMMARY
#        Feature  Correlation
#    indice_gini    -0.061855
# pib_per_capita     0.012470

# %% [markdown]
# Macroeconomic indicators of wealth and income distribution do not show a significant correlation with female representation in management positions in the data analyzed.

# %% [markdown]
# ## Question 3: what is the relationship between employment quality and female leadership?

# %%
employment_features = ['participacao_trabalho_feminina', 'razao_fm_participacao_trabalho', 
                       'desemprego_feminino', 'empregadas_assalariadas']
emp_corr = plot_correlation_analysis(
    X, y,
    features=employment_features,
    feature_category='Employment quality',
    top_n=3,
    color='coral'
)
# Out:
# EMPLOYMENT QUALITY - CORRELATION SUMMARY
#                        Feature  Correlation
# razao_fm_participacao_trabalho    -0.255744
# participacao_trabalho_feminina    -0.229479
#        empregadas_assalariadas     0.078316
#            desemprego_feminino     0.002579

# %% [markdown]
# Overall labor market participation has a negative correlation with female leadership, while female employment in the "salaried" category shows a slightly positive correlation.

# %% [markdown]
# # 5. Predictive modeling

# %%
# Train models
analyzer.train_models(test_size=0.2, random_state=42)
# Out:
# Training models...
#
#    Training Linear Regression...
#       R² Test: 0.6773
#       MAE Test: 2.4286
#       CV R²: 0.2522 ± 0.2719
#
#    Training Random Forest...
#       R² Test: 0.8525
#       MAE Test: 1.7226
#       CV R²: 0.5098 ± 0.2049
#
#    Training Gradient Boosting...
#       R² Test: 0.8888
#       MAE Test: 1.3354
#       CV R²: 0.5254 ± 0.0925
#
# All models trained!
# {'Linear Regression': LinearRegression(),
#  'Random Forest': RandomForestRegressor(max_depth=10, random_state=42),
#  'Gradient Boosting': GradientBoostingRegressor(max_depth=5, random_state=42)}

# %%
comparison = analyzer.plot_model_comparison(figsize=(16, 5))
plt.suptitle('Model Performance Comparison - Can We Predict Female Leadership?', 
             fontsize=14, fontweight='bold', y=1.02)
plt.show()

print("\nDetailed Metrics:")
print(comparison.to_string())

# Best model
best_model = comparison['test_r2'].idxmax()
best_r2 = comparison.loc[best_model, 'test_r2']
best_mae = comparison.loc[best_model, 'test_mae']

print(f"\nBest Model: {best_model}")
print(f"   R² Score: {best_r2:.4f} ({best_r2*100:.1f}% of variance explained)")
print(f"   MAE: {best_mae:.4f} percentage points")
print(f"   Models explain {best_r2*100:.1f}% of variation with {best_mae:.2f}pp average error.")
# Out:
# Detailed Metrics:
#                    train_r2   test_r2  train_mae  test_mae  train_rmse  test_rmse  cv_r2_mean  cv_r2_std
# Linear Regression  0.505535  0.677294   3.127165  2.428609    4.154992   3.211343    0.252164   0.271892
# Random Forest      0.947793  0.852492   0.925033  1.722649    1.350101   2.171156    0.509769   0.204908
# Gradient Boosting  0.999974  0.888768   0.024539  1.335401    0.029964   1.885375    0.525396   0.092454
#
# Best Model: Gradient Boosting
#    R² Score: 0.8888 (88.9% of variance explained)
#    MAE: 1.3354 percentage points
#    Models explain 88.9% of variation with 1.34pp average error.

# %% [markdown]
# ## Question 4: which interventions provide the highest ROI?

# %%
importance_df = analyzer.plot_feature_importance('Random Forest', top_n=15, figsize=(14, 8))
plt.show()

print("\nTop 10 Most Important Features:")
print(importance_df.head(10).to_string(index=False))

print("\n" + "=" * 80)
print("STRATEGIC PRIORITIZATION")
print("=" * 80)
print("\nBased on feature importance, prioritize interventions in:")
for idx, row in importance_df.head(5).iterrows():
    print(f"\n{idx+1}. {row['Feature']}")
    print(f"   Impact Score: {row['Importance']:.4f}")
    print(f"   → HIGH ROI candidate for policy intervention")
# Out:
# Top 10 Most Important Features:
#                           Feature  Importance
#     matricula_secundaria_feminina    0.375203
#           empregados_assalariados    0.150404
#       matricula_superior_feminina    0.079228
#  desemprego_edu_avancada_feminino    0.066337
#                pct_graduadas_stem    0.056819
#                       indice_gini    0.053930
#                    pib_per_capita    0.036561
#                      uso_internet    0.035570
# desemprego_edu_avancada_masculino    0.035202
#               desemprego_feminino    0.033827
#
# ================================================================================
# STRATEGIC PRIORITIZATION
# ================================================================================
#
# Based on feature importance, prioritize interventions in:
#
# 8. matricula_secundaria_feminina
#    Impact Score: 0.3752
#    → HIGH ROI candidate for policy intervention
#
# 6. empregados_assalariados
#    Impact Score: 0.1504
#    → HIGH ROI candidate for policy intervention
#
# 9. matricula_superior_feminina
#    Impact Score: 0.0792
#    → HIGH ROI candidate for policy intervention
#
# 1. desemprego_edu_avancada_feminino
#    Impact Score: 0.0663
#    → HIGH ROI candidate for policy intervention
#
# 12. pct_graduadas_stem
#    Impact Score: 0.0568
#    → HIGH ROI candidate for policy intervention
